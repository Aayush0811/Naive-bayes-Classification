# %%
import pandas as pd

# %%
data = pd.read_csv("data.csv")

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
data.shape
# Out:
# (569, 33)

# %%
filtered_data = data.drop([data.columns[0],data.columns[32]],axis=1)

# %%
filtered_data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M       17.990         10.38          122.80     1001.0
# 1           M       20.570         17.77          132.90     1326.0
# 2           M       19.690         21.25          130.00     1203.0
# 3           M       11.420         20.38           77.58      386.1
# 4           M       20.290         14.34          135.10     1297.0
# 5           M       12.450         15.70           82.57      477.1
# 6           M       18.250         19.98          119.60     1040.0
# 7           M       13.710         20.83           90.20      577.9
# 8           M       13.000         21.82           87.50      519.8
# 9           M       12.460         24.04           83.97      475.9
# 10          M       16.020         23.24          102.70      797.8
# 11          M       15.780         17.89          103.60      781.0
# 12          M       19.170         24.80          132.40     1123.0
# ...

# %%
B_data = filtered_data[filtered_data['diagnosis'] == 'B']

# %%
B_data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 19          B       13.540         14.36           87.46      566.3
# 20          B       13.080         15.71           85.63      520.0
# 21          B        9.504         12.44           60.34      273.9
# 37          B       13.030         18.42           82.61      523.8
# 46          B        8.196         16.84           51.71      201.9
# 48          B       12.050         14.63           78.04      449.3
# 49          B       13.490         22.30           86.91      561.0
# 50          B       11.760         21.60           74.72      427.9
# 51          B       13.640         16.34           87.21      571.8
# 52          B       11.940         18.24           75.71      437.6
# 55          B       11.520         18.75           73.34      409.0
# 58          B       13.050         19.31           82.61      527.2
# 59          B        8.618         11.79           54.34      224.5
# ...

# %%
M_data = filtered_data[filtered_data['diagnosis'] == 'M']

# %%
M_data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# 5           M        12.45         15.70           82.57      477.1
# 6           M        18.25         19.98          119.60     1040.0
# 7           M        13.71         20.83           90.20      577.9
# 8           M        13.00         21.82           87.50      519.8
# 9           M        12.46         24.04           83.97      475.9
# 10          M        16.02         23.24          102.70      797.8
# 11          M        15.78         17.89          103.60      781.0
# 12          M        19.17         24.80          132.40     1123.0
# ...

# %%
B_data = B_data.iloc[:,0:3]

# %%
B_data
# Out:
#     diagnosis  radius_mean  texture_mean
# 19          B       13.540         14.36
# 20          B       13.080         15.71
# 21          B        9.504         12.44
# 37          B       13.030         18.42
# 46          B        8.196         16.84
# 48          B       12.050         14.63
# 49          B       13.490         22.30
# 50          B       11.760         21.60
# 51          B       13.640         16.34
# 52          B       11.940         18.24
# 55          B       11.520         18.75
# 58          B       13.050         19.31
# 59          B        8.618         11.79
# 60          B       10.170         14.88
# 61          B        8.598         20.98
# 63          B        9.173         13.86
# 66          B        9.465         21.01
# 67          B       11.310         19.04
# 68          B        9.029         17.33
# 69          B       12.780         16.49
# 71          B        8.888         14.64
# 74          B       12.310         16.52
# ...

# %%
M_data = M_data.iloc[:,0:3]

# %%
M_data
# Out:
#     diagnosis  radius_mean  texture_mean
# 0           M        17.99         10.38
# 1           M        20.57         17.77
# 2           M        19.69         21.25
# 3           M        11.42         20.38
# 4           M        20.29         14.34
# 5           M        12.45         15.70
# 6           M        18.25         19.98
# 7           M        13.71         20.83
# 8           M        13.00         21.82
# 9           M        12.46         24.04
# 10          M        16.02         23.24
# 11          M        15.78         17.89
# 12          M        19.17         24.80
# 13          M        15.85         23.95
# 14          M        13.73         22.61
# 15          M        14.54         27.54
# 16          M        14.68         20.13
# 17          M        16.13         20.68
# 18          M        19.81         22.15
# 22          M        15.34         14.26
# 23          M        21.16         23.04
# 24          M        16.65         21.38
# ...

# %%
training_data_len = int(0.7 * len(filtered_data))

# %%
training_data_len
# Out:
# 398

# %%
category_data_len = training_data_len//2

# %%
category_data_len
# Out:
# 199

# %%
B_train_data = B_data.iloc[0:category_data_len,:]

# %%
B_train_data
# Out:
#     diagnosis  radius_mean  texture_mean
# 19          B       13.540         14.36
# 20          B       13.080         15.71
# 21          B        9.504         12.44
# 37          B       13.030         18.42
# 46          B        8.196         16.84
# 48          B       12.050         14.63
# 49          B       13.490         22.30
# 50          B       11.760         21.60
# 51          B       13.640         16.34
# 52          B       11.940         18.24
# 55          B       11.520         18.75
# 58          B       13.050         19.31
# 59          B        8.618         11.79
# 60          B       10.170         14.88
# 61          B        8.598         20.98
# 63          B        9.173         13.86
# 66          B        9.465         21.01
# 67          B       11.310         19.04
# 68          B        9.029         17.33
# 69          B       12.780         16.49
# 71          B        8.888         14.64
# 74          B       12.310         16.52
# ...

# %%
M_train_data = M_data.iloc[0:category_data_len,:]

# %%
M_train_data
# Out:
#     diagnosis  radius_mean  texture_mean
# 0           M        17.99         10.38
# 1           M        20.57         17.77
# 2           M        19.69         21.25
# 3           M        11.42         20.38
# 4           M        20.29         14.34
# 5           M        12.45         15.70
# 6           M        18.25         19.98
# 7           M        13.71         20.83
# 8           M        13.00         21.82
# 9           M        12.46         24.04
# 10          M        16.02         23.24
# 11          M        15.78         17.89
# 12          M        19.17         24.80
# 13          M        15.85         23.95
# 14          M        13.73         22.61
# 15          M        14.54         27.54
# 16          M        14.68         20.13
# 17          M        16.13         20.68
# 18          M        19.81         22.15
# 22          M        15.34         14.26
# 23          M        21.16         23.04
# 24          M        16.65         21.38
# ...

# %%
B_test_data = B_data.iloc[category_data_len:,:]

M_test_data = M_data.iloc[category_data_len:,:]

# %%
testing_data = pd.concat([B_test_data,M_test_data])

# %%
testing_data
# Out:
#     diagnosis  radius_mean  texture_mean
# 360         B       12.540         18.07
# 361         B       13.300         21.57
# 362         B       12.760         18.84
# 363         B       16.500         18.29
# 364         B       13.400         16.95
# 367         B       12.210         18.02
# 371         B       15.190         13.21
# 374         B       13.690         16.07
# 375         B       16.170         16.07
# 376         B       10.570         20.22
# 377         B       13.460         28.21
# 378         B       13.660         15.15
# 380         B       11.270         12.96
# 381         B       11.040         14.93
# 382         B       12.050         22.72
# 383         B       12.390         17.48
# 384         B       13.280         13.72
# 386         B       12.210         14.09
# 387         B       13.880         16.16
# 388         B       11.270         15.50
# 390         B       10.260         12.22
# 391         B        8.734         16.84
# ...

# %%
training_data = pd.concat([B_train_data,M_train_data])

# %%
training_data
# Out:
#     diagnosis  radius_mean  texture_mean
# 19          B       13.540         14.36
# 20          B       13.080         15.71
# 21          B        9.504         12.44
# 37          B       13.030         18.42
# 46          B        8.196         16.84
# 48          B       12.050         14.63
# 49          B       13.490         22.30
# 50          B       11.760         21.60
# 51          B       13.640         16.34
# 52          B       11.940         18.24
# 55          B       11.520         18.75
# 58          B       13.050         19.31
# 59          B        8.618         11.79
# 60          B       10.170         14.88
# 61          B        8.598         20.98
# 63          B        9.173         13.86
# 66          B        9.465         21.01
# 67          B       11.310         19.04
# 68          B        9.029         17.33
# 69          B       12.780         16.49
# 71          B        8.888         14.64
# 74          B       12.310         16.52
# ...

# %%
M_train_features = training_data[training_data['diagnosis'] == 'M'].iloc[:,1:3]

# %%
B_train_features = training_data[training_data['diagnosis'] == 'B'].iloc[:,1:3]

# %%
M_train_features
# Out:
#      radius_mean  texture_mean
# 0          17.99         10.38
# 1          20.57         17.77
# 2          19.69         21.25
# 3          11.42         20.38
# 4          20.29         14.34
# 5          12.45         15.70
# 6          18.25         19.98
# 7          13.71         20.83
# 8          13.00         21.82
# 9          12.46         24.04
# 10         16.02         23.24
# 11         15.78         17.89
# 12         19.17         24.80
# 13         15.85         23.95
# 14         13.73         22.61
# 15         14.54         27.54
# 16         14.68         20.13
# 17         16.13         20.68
# 18         19.81         22.15
# 22         15.34         14.26
# 23         21.16         23.04
# 24         16.65         21.38
# 25         17.14         16.40
# 26         14.58         21.53
# 27         18.61         20.25
# 28         15.30         25.27
# 29         17.57         15.05
# 30         18.63         25.11
# 31         11.84         18.70
# ...

# %%
B_train_features
# Out:
#      radius_mean  texture_mean
# 19        13.540         14.36
# 20        13.080         15.71
# 21         9.504         12.44
# 37        13.030         18.42
# 46         8.196         16.84
# 48        12.050         14.63
# 49        13.490         22.30
# 50        11.760         21.60
# 51        13.640         16.34
# 52        11.940         18.24
# 55        11.520         18.75
# 58        13.050         19.31
# 59         8.618         11.79
# 60        10.170         14.88
# 61         8.598         20.98
# 63         9.173         13.86
# 66         9.465         21.01
# 67        11.310         19.04
# 68         9.029         17.33
# 69        12.780         16.49
# 71         8.888         14.64
# 74        12.310         16.52
# 76        13.530         10.94
# 79        12.860         18.00
# 80        11.450         20.97
# 81        13.340         15.86
# 84        12.000         15.65
# 88        12.360         21.80
# 89        14.640         15.24
# ...

# %%
import matplotlib.pyplot as plt

import seaborn as sns

# %%
plt.figure(figsize=(7,7))

plt.scatter(M_train_features['radius_mean'],M_train_features['texture_mean'])

plt.xlabel('radius_mean|diagnosis = M')

plt.ylabel('texture_mean|diagnosis= M')
# Out:
# Text(0, 0.5, 'texture_mean|diagnosis= M')

# %%
plt.figure(figsize=(7,7))

plt.scatter(B_train_features['radius_mean'],B_train_features['texture_mean'])

plt.xlabel('radius_mean|diagnosis = B')

plt.ylabel('texture_mean|diagnosis= B')
# Out:
# Text(0, 0.5, 'texture_mean|diagnosis= B')

# %%
import numpy as np

# %%
def normal_likelihood(training_features):
    
    training_features = np.array(training_features)
    
    mu_cap = np.mean(training_features)
    
    sigma_cap = np.std(training_features)
    
    return -np.sum(np.log(s.norm.pdf(mu_cap,sigma_cap,training_features)))

# %%
def rayliegh_likelihood(training_features):
    
    training_features = np.array(training_features)
    
    sigma_cap = np.sqrt(np.mean(training_features**2)/2)
    
    return -np.sum(np.log(s.rayleigh.pdf(sigma_cap,training_features)))

# %%
def determine_distribution(training_features):
    
    if normal_likelihood(training_features) < rayliegh_likelihood(training_features):
        
        return (np.mean(training_features), np.std(training_features))
    
    else:
        
        return np.sqrt(np.mean(training_features**2)/2)

# %%
M_means = M_train_features.mean()

# %%
M_means
# Out:
# radius_mean     17.356382
# texture_mean    21.461759
# dtype: float64

# %%
#M_parameters = determine_distribution(M_train_features)

M_cov = M_train_features.cov()

# %%
M_cov
# Out:
#               radius_mean  texture_mean
# radius_mean     10.200581      1.231750
# texture_mean     1.231750     13.931953

# %%
M_parameters = (M_means, M_cov)

# %%
B_means = B_train_features.mean()

# %%
B_means
# Out:
# radius_mean     11.984397
# texture_mean    17.110905
# dtype: float64

# %%
B_cov = B_train_features.cov()

# %%
B_cov
# Out:
#               radius_mean  texture_mean
# radius_mean      2.940920      0.151939
# texture_mean     0.151939     11.328855

# %%
B_parameters = (B_means, B_cov)

# %%
sns.pairplot(training_data, hue='diagnosis',height=5)

# %%
from matplotlib import cm

from mpl_toolkits.mplot3d import Axes3D

import scipy.stats as s

import numpy as np

# %%
def plot_multivariate_normal(params):
    
    X = np.linspace(5,30,50)

    Y = np.linspace(5,30,50)
    
    X,Y = np.meshgrid(X,Y)
    
    data = np.empty(X.shape+(2,))
    
    data[:,:,0] = X

    data[:,:,1] = Y
    
    mean_vec = params[0]
    
    cov_mat = params[1]
    
    P_X_equals_x_and_Y_equals_y = s.multivariate_normal.pdf(data,mean=mean_vec,cov=cov_mat)
    
    fig = plt.figure(figsize=(12,12))

    axes = fig.gca(projection='3d')

    axes.plot_surface(X=X,Y=Y,Z=P_X_equals_x_and_Y_equals_y,rstride=3,
                  cstride=3,linewidth=1,antialiased=True,cmap=cm.viridis)

    axes.contourf(X=X,Y=Y,Z=P_X_equals_x_and_Y_equals_y,zdir='z',cmap=cm.viridis,offset=-0.15)

    axes.set_zlim(-0.15,0.2)

    axes.set_zticks(np.linspace(0,0.2,5))

    axes.view_init(27,-21)

    plt.show()

# %%
plot_multivariate_normal(B_parameters)

# %%
plot_multivariate_normal(M_parameters)

# %%
def P_diagnosis_equals_M_on_features(testing_data_features):
    
    likelihood_m = s.multivariate_normal.pdf(testing_data_features,M_parameters[0],M_parameters[1])
    
    likelihood_b = s.multivariate_normal.pdf(testing_data_features,B_parameters[0],B_parameters[1])
    
    posterior_m = likelihood_m/(likelihood_m + likelihood_b)
    
    return posterior_m > 0.5

# %%
testing_data_posterior_m = P_diagnosis_equals_M_on_features(testing_data.iloc[:,1:3])

# %%
testing_data_posterior_m = pd.Series(data=testing_data_posterior_m)

# %%
testing_data_posterior_m.replace(to_replace=[False,True],value=['B','M'],inplace=True)

# %%
predicted_diagnosis = np.array(testing_data_posterior_m)

# %%
actual_diagnosis = np.array(testing_data['diagnosis'])

# %%
actual_diagnosis
# Out:
# array(['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M'], dtype=object)

# %%
predicted_diagnosis
# Out:
# array(['B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'M', 'B', 'B', 'M', 'M', 'M', 'M', 'M', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'M', 'B', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'M',
#        'M', 'B', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M'], dtype=object)

# %%
correct_count = np.count_nonzero(predicted_diagnosis == actual_diagnosis)

# %%
correct_count
# Out:
# 139

# %%
accuracy = correct_count/actual_diagnosis.shape[0]

# %%
accuracy
# Out:
# 0.8128654970760234

# %% [markdown]
# # Computation of Precision and Recall here for Homework
